# %%
import rpy2.robjects as robjects
from rpy2.robjects.packages import importr

# %%
#import R packages
e1071 = importr('e1071')
fclust = importr('fclust')
ppclust = importr('ppclust')

# %% [markdown]
# # R package contents
#
# [e1071](https://cran.r-project.org/web/packages/e1071/e1071.pdf) : contains functions cmeans (dist is euclidean, this is what has been used up until now)
#
# [fclust](https://cran.r-project.org/web/packages/fclust/fclust.pdf) : contains functions fkm (dist is euclidean, equivalent to cmeans from e1071 package, for all I can tell), fkm.gkb (dist is mahalanobis), NEFRC (accepts distance and dissimilarity matrices as input). Also includes a variety of clustering indices:
#
# | call   |      Description      |  Optimization |
# |----------|:-------------:|------:|
# | XB |    Xie-Beni   |   min |
# | PE |    Partition entropy   |   min |
# | PC |    Partition coefficient   |   max |
# | MPC |    Modified partition coefficient   |   max |
# | SIL |    Silhouette index   |   max |
# | SIL.F |    Fuzzy silhouette index   |   max |
#
# [ppclust](https://cran.r-project.org/web/packages/ppclust/ppclust.pdf) : can cluster on a wide variety of distance metrics, but is very slow based on testing in R thus far, might only be useful for creating various distance matrices:
#
# | dmetric   |      Description      |  Norm |
# |----------|:-------------:|------:|
# | addsymchi |    Additive Symmetric   |   sl2 |
# | canberra |    Canberra   |   l1 |
# | chebyshev |    Chebyshev   |   li |
# | clark |    Clark   |   sl2 |
# | correlation |    Correlation   |   cor |
# | cosine |    Cosine   |   cos |
# | divergence |    Divergence   |   sl2 |
# | euclidean |    Euclidean   |   l2 |
# | lorentzian |    Lorentzian   |   l1 |
# | manhattan |    Manhattan   |   l1 |
# | minkowski |    Minkowski   |   lp |
# | neymanchi |    Neyman Chi   |   sl2 |
# | pearsonchi |    Pearson Chi   |   sl2 |
# | prosymchi |    Probabilistic Symmetric   |   sl2 |
# | sorensen |    Sorensen   |   l1 |
# | sqchi |    Squared Chi   |   sl2 |
# | sqchord |    Squared Chord   |   sc |
# | sqeuclidean |    Squared Euclidean   |   sl2 |

# %%
#load functions
cmeansCRAN = e1071.cmeans
'''centers, size, cluster, iter, membership, withinerror, call = cmeans(
        x, centers, iter.max = 100, verbose = FALSE,
        dist = "euclidean", method = "cmeans", m = 2,
        rate.par = NULL, weights = 1, control = list())'''
fclustFKM = fclust.FKM
'''U, H, F, clus, medoid, value, iter, k, m, ent, b, vp, delta, gam, mcn, Xca, X, D, call = FKM(
        X, k, m, RS, stand, startU, index, alpha, conv, maxit, seed)'''
fclustFKMGKB = fclust.FKM_gkb  # translation of FKM.gkb in R
'''U, H, F, clus, medoid, value, criterion, iter, k, m, ent, b, vp, delta, gam, mcn, stand, Xca, X, D, call = FKM.gkb(
        X, k, m, vp, gam, mcn, RS, stand, startU, index, alpha, conv, maxit, seed)'''
fclustNEFRC = fclust.NEFRC
'''U, H, F, clus, medoid, value, criterion, iter, k, m, ent, b, vp, delta, stand, Xca, X, D, call = NEFRD(
        (D, k, m, RS, startU, index, alpha, conv, maxit, seed)'''
# hold the thought adding the distance matrix functions from ppclust
# Out:
# 'U, H, F, clus, medoid, value, criterion, iter, k, m, ent, b, vp, delta, stand, Xca, X, D, call = NEFRD(\n        (D, k, m, RS, startU, index, alpha, conv, maxit, seed)'

# %% [markdown]
# ## generate test cluster data

# %%
fclustFKMGKB = fclust.FKM_gkb

# %%
vars(fclust)
# Out:
# {'__name__': 'fclust',
#  '__doc__': None,
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '_env': <rpy2.rinterface_lib.sexp.SexpEnvironment object at 0x7f991c8efe40> [RTYPES.ENVSXP],
#  '__rname__': 'fclust',
#  '_translation': {},
#  '_rpy2r': {'_fclust_centroids_FKM': '_fclust_centroids_FKM',
#   '_fclust_centroids_FKM_ent': '_fclust_centroids_FKM_ent',
#   '_fclust_centroids_FKM_pf': '_fclust_centroids_FKM_pf',
#   '_fclust_distCheck': '_fclust_distCheck',
#   '_fclust_euclidean_distance': '_fclust_euclidean_distance',
#   '_fclust_euclidean_distance_gk': '_fclust_euclidean_distance_gk',
#   '_fclust_euclidean_distance_gkb': '_fclust_euclidean_distance_gkb',
#   '_fclust_euclidean_distance_medoid': '_fclust_euclidean_distance_medoid',
#   '_fclust_F_gk': '_fclust_F_gk',
#   '_fclust_F_gk_ent': '_fclust_F_gk_ent',
#   '_fclust_F_gkb': '_fclust_F_gkb',
#   '_fclust_F_gkb_ent': '_fclust_F_gkb_ent',
#   '_fclust_indices': '_fclust_indices',
#   '_fclust_InvCheck': '_fclust_InvCheck',
#   '_fclust_mainFKM': '_fclust_mainFKM',
#   '_fclust_mainFKM_ent': '_fclust_mainFKM_ent',
#   '_fclust_mainFKM_ent_noise': '_fclust_mainFKM_ent_noise',
#   '_fclust_mainFKM_ent_noise_U': '_fclust_mainFKM_ent_noise_U',
#   '_fclust_mainFKM_ent_U': '_fclust_mainFKM_ent_U',
#   '_fclust_mainFKM_gk': '_fclust_mainFKM_gk',
#   '_fclust_mainFKM_gk_ent': '_fclust_mainFKM_gk_ent',
#   '_fclust_mainFKM_gk_ent_noise': '_fclust_mainFKM_gk_ent_noise',
#   '_fclust_mainFKM_gk_ent_noise_U': '_fclust_mainFKM_gk_ent_noise_U',
#   '_fclust_mainFKM_gk_ent_U': '_fclust_mainFKM_gk_ent_U',
#   '_fclust_mainFKM_gk_noise': '_fclust_mainFKM_gk_noise',
#   '_fclust_mainFKM_gk_noise_U': '_fclust_mainFKM_gk_noise_U',
#   '_fclust_mainFKM_gk_U': '_fclust_mainFKM_gk_U',
#   '_fclust_mainFKM_gkb': '_fclust_mainFKM_gkb',
#   '_fclust_mainFKM_gkb_ent': '_fclust_mainFKM_gkb_ent',
#   '_fclust_mainFKM_gkb_ent_noise': '_fclust_mainFKM_gkb_ent_noise',
#   '_fclust_mainFKM_gkb_ent_noise_U': '_fclust_mainFKM_gkb_ent_noise_U',
#   '_fclust_mainFKM_gkb_ent_U': '_fclust_mainFKM_gkb_ent_U',
#   '_fclust_mainFKM_gkb_noise': '_fclust_mainFKM_gkb_noise',
#   '_fclust_mainFKM_gkb_noise_U': '_fclust_mainFKM_gkb_noise_U',
#   '_fclust_mainFKM_gkb_U': '_fclust_mainFKM_gkb_U',
#   '_fclust_mainFKM_med': '_fclust_mainFKM_med',
#   '_fclust_mainFKM_med_noise': '_fclust_mainFKM_med_noise',
#   '_fclust_mainFKM_med_noise_U': '_fclust_mainFKM_med_noise_U',
#   '_fclust_mainFKM_med_U': '_fclust_mainFKM_med_U',
#   '_fclust_mainFKM_noise': '_fclust_mainFKM_noise',
#   '_fclust_mainFKM_noise_U': '_fclust_mainFKM_noise_U',
#   '_fclust_mainFKM_pf': '_fclust_mainFKM_pf',
#   '_fclust_mainFKM_pf_noise': '_fclust_mainFKM_pf_noise',
#   '_fclust_mainFKM_pf_noise_U': '_fclust_mainFKM_pf_noise_U',
#   '_fclust_mainFKM_pf_U': '_fclust_mainFKM_pf_U',
#   '_fclust_mainFKM_U': '_fclust_mainFKM_U',
#   '_fclust_mainnefrc': '_fclust_mainnefrc',
#   '_fclust_mainnefrc_U': '_fclust_mainnefrc_U',
#   '_fclust_mainrnefrc': '_fclust_mainrnefrc',
#   '_fclust_mainrnefrc_U': '_fclust_mainrnefrc_U',
#   '_fclust_Match': '_fclust_Match',
#   '_fclust_medoids_FKM': '_fclust_medoids_FKM',
#   '_fclust_memb_degree': '_fclust_memb_degree',
#   '_fclust_memb_degree_ent': '_fclust_memb_degree_ent',
#   '_fclust_memb_degree_medoid': '_fclust_memb_degree_medoid',
#   '_fclust_memb_degree_pf': '_fclust_memb_degree_pf',
#   '_fclust_partCoef': '_fclust_partCoef',
#   '_fclust_partCoef_mod': '_fclust_partCoef_mod',
#   '_fclust_partEntropy': '_fclust_partEntropy',
#   '_fclust_partition_comp': '_fclust_partition_comp',
#   '_fclust_replace': '_fclust_replace',
#   '_fclust_silhouette': '_fclust_silhouette',
#   '_fclust_silhouette_internal': '_fclust_silhouette_internal',
#   '_fclust_silhouetteFuzzy': '_fclust_silhouetteFuzzy',
#   '_fclust_unifInit': '_fclust_unifInit',
#   '_fclust_xie_beni': '_fclust_xie_beni',
#   '___NAMESPACE___': '.__NAMESPACE__.',
#   '___S3MethodsTable___': '.__S3MethodsTable__.',
#   '_onLoad': '.onLoad',
#   '_onUnload': '.onUnload',
#   '_packageName': '.packageName',
#   'ARI_F': 'ARI.F',
#   'centroids_FKM': 'centroids_FKM',
#   'centroids_FKM_ent': 'centroids_FKM_ent',
#   'centroids_FKM_pf': 'centroids_FKM_pf',
#   'cl_memb': 'cl.memb',
#   'cl_memb_H': 'cl.memb.H',
#   'cl_memb_t': 'cl.memb.t',
#   'cl_size': 'cl.size',
#   'cl_size_H': 'cl.size.H',
#   'distCheck': 'distCheck',
#   'euclidean_distance': 'euclidean_distance',
#   'euclidean_distance_gk': 'euclidean_distance_gk',
#   'euclidean_distance_gkb': 'euclidean_distance_gkb',
#   'euclidean_distance_medoid': 'euclidean_distance_medoid',
#   'F_gk': 'F_gk',
#   'F_gk_ent': 'F_gk_ent',
#   'F_gkb': 'F_gkb',
#   'F_gkb_ent': 'F_gkb_ent',
#   'Fclust': 'Fclust',
#   'Fclust_compare': 'Fclust.compare',
#   'Fclust_index': 'Fclust.index',
#   'FKM': 'FKM',
#   'FKM_ent': 'FKM.ent',
#   'FKM_ent_noise': 'FKM.ent.noise',
#   'FKM_gk': 'FKM.gk',
#   'FKM_gk_ent': 'FKM.gk.ent',
#   'FKM_gk_ent_noise': 'FKM.gk.ent.noise',
#   'FKM_gk_noise': 'FKM.gk.noise',
#   'FKM_gkb': 'FKM.gkb',
#   'FKM_gkb_ent': 'FKM.gkb.ent',
#   'FKM_gkb_ent_noise': 'FKM.gkb.ent.noise',
#   'FKM_gkb_noise': 'FKM.gkb.noise',
#   'FKM_med': 'FKM.med',
#   'FKM_med_noise': 'FKM.med.noise',
#   'FKM_noise': 'FKM.noise',
#   'FKM_pf': 'FKM.pf',
#   'FKM_pf_noise': 'FKM.pf.noise',
#   'Hraw': 'Hraw',
#   'indices': 'indices',
#   'InvCheck': 'InvCheck',
#   'JACCARD_F': 'JACCARD.F',
#   'mainFKM': 'mainFKM',
#   'mainFKM_ent': 'mainFKM_ent',
#   'mainFKM_ent_noise': 'mainFKM_ent_noise',
#   'mainFKM_ent_noise_U': 'mainFKM_ent_noise_U',
#   'mainFKM_ent_U': 'mainFKM_ent_U',
#   'mainFKM_gk': 'mainFKM_gk',
#   'mainFKM_gk_ent': 'mainFKM_gk_ent',
#   'mainFKM_gk_ent_noise': 'mainFKM_gk_ent_noise',
#   'mainFKM_gk_ent_noise_U': 'mainFKM_gk_ent_noise_U',
#   'mainFKM_gk_ent_U': 'mainFKM_gk_ent_U',
#   'mainFKM_gk_noise': 'mainFKM_gk_noise',
#   'mainFKM_gk_noise_U': 'mainFKM_gk_noise_U',
#   'mainFKM_gk_U': 'mainFKM_gk_U',
#   'mainFKM_gkb': 'mainFKM_gkb',
#   'mainFKM_gkb_ent': 'mainFKM_gkb_ent',
#   'mainFKM_gkb_ent_noise': 'mainFKM_gkb_ent_noise',
#   'mainFKM_gkb_ent_noise_U': 'mainFKM_gkb_ent_noise_U',
#   'mainFKM_gkb_ent_U': 'mainFKM_gkb_ent_U',
#   'mainFKM_gkb_noise': 'mainFKM_gkb_noise',
#   'mainFKM_gkb_noise_U': 'mainFKM_gkb_noise_U',
#   'mainFKM_gkb_U': 'mainFKM_gkb_U',
#   'mainFKM_med': 'mainFKM_med',
#   'mainFKM_med_noise': 'mainFKM_med_noise',
#   'mainFKM_med_noise_U': 'mainFKM_med_noise_U',
#   'mainFKM_med_U': 'mainFKM_med_U',
#   'mainFKM_noise': 'mainFKM_noise',
#   'mainFKM_noise_U': 'mainFKM_noise_U',
#   'mainFKM_pf': 'mainFKM_pf',
#   'mainFKM_pf_noise': 'mainFKM_pf_noise',
#   'mainFKM_pf_noise_U': 'mainFKM_pf_noise_U',
#   'mainFKM_pf_U': 'mainFKM_pf_U',
#   'mainFKM_U': 'mainFKM_U',
#   'mainnefrc': 'mainnefrc',
#   'mainnefrc_U': 'mainnefrc_U',
#   'mainrnefrc': 'mainrnefrc',
#   'mainrnefrc_U': 'mainrnefrc_U',
#   'Match': 'Match',
#   'medoids_FKM': 'medoids_FKM',
#   'memb_degree': 'memb_degree',
#   'memb_degree_ent': 'memb_degree_ent',
#   'memb_degree_medoid': 'memb_degree_medoid',
#   'memb_degree_pf': 'memb_degree_pf',
#   'MPC': 'MPC',
#   'NEFRC': 'NEFRC',
#   'NEFRC_noise': 'NEFRC.noise',
#   'partCoef': 'partCoef',
#   'partCoef_mod': 'partCoef_mod',
#   'partEntropy': 'partEntropy',
#   'partition_comp': 'partition_comp',
#   'PC': 'PC',
#   'PE': 'PE',
#   'plot_fclust': 'plot.fclust',
#   'plotFKM': 'plotFKM',
#   'plotREL': 'plotREL',
#   'print_fclust': 'print.fclust',
#   'replace': 'replace',
#   'RI_F': 'RI.F',
#   'SIL': 'SIL',
#   'SIL_F': 'SIL.F',
#   'silhouette': 'silhouette',
#   'silhouette_internal': 'silhouette_internal',
#   'silhouetteFuzzy': 'silhouetteFuzzy',
#   'summary_fclust': 'summary.fclust',
#   'unifInit': 'unifInit',
#   'VAT': 'VAT',
#   'VCV': 'VCV',
#   'VCV2': 'VCV2',
#   'VIFCR': 'VIFCR',
#   'XB': 'XB',
#   'xie_beni': 'xie_beni'},
#  '_exported_names': {'ARI_F',
#   'FKM',
#   'FKM_ent',
#   'FKM_ent_noise',
#   'FKM_gk',
#   'FKM_gk_ent',
#   'FKM_gk_ent_noise',
#   'FKM_gk_noise',
#   'FKM_gkb',
#   'FKM_gkb_ent',
#   'FKM_gkb_ent_noise',
#   'FKM_gkb_noise',
#   'FKM_med',
#   'FKM_med_noise',
#   'FKM_noise',
#   'FKM_pf',
#   'FKM_pf_noise',
#   'Fclust',
#   'Fclust_compare',
#   'Fclust_index',
#   'Hraw',
#   'JACCARD_F',
#   'MPC',
#   'NEFRC',
#   'NEFRC_noise',
#   'PC',
#   'PE',
#   'RI_F',
#   'SIL',
#   'SIL_F',
#   'VAT',
#   'VCV',
#   'VCV2',
#   'VIFCR',
#   'XB',
#   'cl_memb',
#   'cl_memb_H',
#   'cl_memb_t',
#   'cl_size',
#   'cl_size_H',
#   'plot_fclust',
#   'print_fclust',
#   'summary_fclust'},
#  '_symbol_r2python': <function rpy2.robjects.packages_utils.default_symbol_r2python(rname)>,
#  '_symbol_resolve': <function rpy2.robjects.packages_utils.default_symbol_resolve(symbol_mapping)>,
#  '_fclust_centroids_FKM': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c3640> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c8efbc0> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c35c0> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c3880> [RTYPES.INTSXP],
#  '_fclust_centroids_FKM_ent': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c3700> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c3780> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c3b80> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c3d00> [RTYPES.INTSXP],
#  '_fclust_centroids_FKM_pf': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c3e40> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c3c80> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c51c0> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c5340> [RTYPES.INTSXP],
#  '_fclust_distCheck': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c5480> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c52c0> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c57c0> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c5940> [RTYPES.INTSXP],
#  '_fclust_euclidean_distance': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c5a80> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c58c0> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c5dc0> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c5f40> [RTYPES.INTSXP],
#  '_fclust_euclidean_distance_gk': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c5f40> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c8080> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c8400> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c8580> [RTYPES.INTSXP],
#  '_fclust_euclidean_distance_gkb': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c86c0> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c8500> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c8a00> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c8b80> [RTYPES.INTSXP],
#  '_fclust_euclidean_distance_medoid': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c8cc0> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c8d80> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c8fc0> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c9140> [RTYPES.INTSXP],
#  '_fclust_F_gk': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c92c0> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c9300> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c9640> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c97c0> [RTYPES.INTSXP],
#  '_fclust_F_gk_ent': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c9900> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c9740> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c9c40> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c9dc0> [RTYPES.INTSXP],
#  '_fclust_F_gkb': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c9dc0> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4ca080> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4ca2c0> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4ca440> [RTYPES.INTSXP],
#  '_fclust_F_gkb_ent': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4ca580> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4ca3c0> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4ca8c0> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4caa40> [RTYPES.INTSXP],
#  '_fclust_indices': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4caa40> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4cabc0> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4caf00> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4cc080> [RTYPES.INTSXP],
#  '_fclust_InvCheck': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4cae80> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4cc0c0> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4cc540> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4cc6c0> [RTYPES.INTSXP],
#  '_fclust_mainFKM': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4cc800> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4cc640> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4ccb40> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4cccc0> [RTYPES.INTSXP],
#  '_fclust_mainFKM_ent': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4caf40> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4cabc0> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4cac40> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4cad40> [RTYPES.INTSXP],
#  '_fclust_mainFKM_ent_noise': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4ca880> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4cab80> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4caf40> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4caec0> [RTYPES.INTSXP],
#  '_fclust_mainFKM_ent_noise_U': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4caf00> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4cad00> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4ca880> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4cad40> [RTYPES.INTSXP],
#  '_fclust_mainFKM_ent_U': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4cabc0> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4ca8c0> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4caf00> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4caec0> [RTYPES.INTSXP],
#  '_fclust_mainFKM_gk': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4cab80> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4caac0> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4cabc0> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4ca300> [RTYPES.INTSXP],
#  '_fclust_mainFKM_gk_ent': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4cad00> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4cabc0> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c9740> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c9bc0> [RTYPES.INTSXP],
#  '_fclust_mainFKM_gk_ent_noise': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c9b00> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c9940> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c99c0> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c95c0> [RTYPES.INTSXP],
#  '_fclust_mainFKM_gk_ent_noise_U': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c9500> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c9480> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c9240> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c9080> [RTYPES.INTSXP],
#  '_fclust_mainFKM_gk_ent_U': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c9380> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c8f40> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c8e40> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c86c0> [RTYPES.INTSXP],
#  '_fclust_mainFKM_gk_noise': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c8880> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c8dc0> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c8080> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c84c0> [RTYPES.INTSXP],
#  '_fclust_mainFKM_gk_noise_U': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c8280> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c87c0> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c8040> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c5dc0> [RTYPES.INTSXP],
#  '_fclust_mainFKM_gk_U': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c58c0> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c5d40> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c5780> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c54c0> [RTYPES.INTSXP],
#  '_fclust_mainFKM_gkb': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c5a00> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c5900> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c5240> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c8efbc0> [RTYPES.INTSXP],
#  '_fclust_mainFKM_gkb_ent': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c81c0> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c3e80> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c3d80> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4b5c00> [RTYPES.INTSXP],
#  '_fclust_mainFKM_gkb_ent_noise': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4b5ec0> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4b9380> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4b9c80> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4b9c40> [RTYPES.INTSXP],
#  '_fclust_mainFKM_gkb_ent_noise_U': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4b95c0> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4bb340> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4bb800> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4bb8c0> [RTYPES.INTSXP],
#  '_fclust_mainFKM_gkb_ent_U': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4bb6c0> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4bbfc0> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4bbb40> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4bb480> [RTYPES.INTSXP],
#  '_fclust_mainFKM_gkb_noise': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c955480> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4ccb00> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4cc940> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4cc540> [RTYPES.INTSXP],
#  '_fclust_mainFKM_gkb_noise_U': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4cc0c0> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4cc6c0> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4cc340> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4cc480> [RTYPES.INTSXP],
#  '_fclust_mainFKM_gkb_U': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4cc180> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4cc2c0> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4d3080> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4d3240> [RTYPES.INTSXP],
#  '_fclust_mainFKM_med': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4d3380> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4d31c0> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4d36c0> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4d3840> [RTYPES.INTSXP],
#  '_fclust_mainFKM_med_noise': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4ccf00> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4cc2c0> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4cc040> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4ccf40> [RTYPES.INTSXP],
#  '_fclust_mainFKM_med_noise_U': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4ccf40> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4ccf00> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4cc280> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4ccfc0> [RTYPES.INTSXP],
#  '_fclust_mainFKM_med_U': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4ccfc0> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4ccf40> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4cc2c0> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4cce80> [RTYPES.INTSXP],
#  '_fclust_mainFKM_noise': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4cce80> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4ccfc0> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4ccf00> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4cc400> [RTYPES.INTSXP],
#  '_fclust_mainFKM_noise_U': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4cc400> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4cce80> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4ccf40> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4cc840> [RTYPES.INTSXP],
#  '_fclust_mainFKM_pf': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4cc840> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4cca80> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4bb6c0> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4bb980> [RTYPES.INTSXP],
#  '_fclust_mainFKM_pf_noise': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4bbc40> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4bbdc0> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4bb300> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4bb0c0> [RTYPES.INTSXP],
#  '_fclust_mainFKM_pf_noise_U': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4bb0c0> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4b9c40> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4b9500> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4b9f80> [RTYPES.INTSXP],
#  '_fclust_mainFKM_pf_U': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4b9880> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4b9400> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4b5a40> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4b5b40> [RTYPES.INTSXP],
#  '_fclust_mainFKM_U': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4b5e40> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c3740> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c3a80> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c5900> [RTYPES.INTSXP],
#  '_fclust_mainnefrc': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c5100> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c53c0> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c5c40> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c5940> [RTYPES.INTSXP],
#  '_fclust_mainnefrc_U': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c58c0> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c5740> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c5f00> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c8040> [RTYPES.INTSXP],
#  '_fclust_mainrnefrc': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c5f40> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c82c0> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c88c0> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c8740> [RTYPES.INTSXP],
#  '_fclust_mainrnefrc_U': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c8540> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c8440> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c8fc0> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c8cc0> [RTYPES.INTSXP],
#  '_fclust_Match': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c8cc0> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f9958202280> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c9480> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c9580> [RTYPES.INTSXP],
#  '_fclust_medoids_FKM': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c95c0> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c9180> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c9b00> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c9a80> [RTYPES.INTSXP],
#  '_fclust_memb_degree': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c9bc0> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c9880> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c9d40> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c9e00> [RTYPES.INTSXP],
#  '_fclust_memb_degree_ent': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c9c40> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4ca300> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4ca200> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4ca100> [RTYPES.INTSXP],
#  '_fclust_memb_degree_medoid': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4ca940> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4caf00> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4caf40> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4ca9c0> [RTYPES.INTSXP],
#  '_fclust_memb_degree_pf': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4cafc0> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4cab00> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4caa40> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4d3780> [RTYPES.INTSXP],
#  '_fclust_partCoef': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4d3900> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4d3880> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4d3300> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4d30c0> [RTYPES.INTSXP],
#  '_fclust_partCoef_mod': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4caf80> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4caa80> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4caf40> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4cae40> [RTYPES.INTSXP],
#  '_fclust_partEntropy': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4cacc0> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4cae80> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4caf80> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4cadc0> [RTYPES.INTSXP],
#  '_fclust_partition_comp': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4caa40> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4caf00> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4cacc0> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4cae40> [RTYPES.INTSXP],
#  '_fclust_replace': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4caa80> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4ca940> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4caa40> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4cadc0> [RTYPES.INTSXP],
#  '_fclust_silhouette': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4cae80> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4ca800> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4caa80> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4ca240> [RTYPES.INTSXP],
#  '_fclust_silhouette_internal': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4ca240> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4ca8c0> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c9d80> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c9fc0> [RTYPES.INTSXP],
#  '_fclust_silhouetteFuzzy': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c9a00> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c9bc0> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c9640> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c9ac0> [RTYPES.INTSXP],
#  '_fclust_unifInit': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c9100> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c92c0> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c9480> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c9200> [RTYPES.INTSXP],
#  '_fclust_xie_beni': R object with classes: ('CallRoutine', 'NativeSymbolInfo') mapped to:
#  [StrSexpVec..., SexpExtPtr, ListSexpVe..., IntSexpVec...]
#    name: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#    <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f991c4c9440> [RTYPES.STRSXP]
#    address: <class 'rpy2.rinterface.SexpExtPtr'>
#    <rpy2.rinterface.SexpExtPtr object at 0x7f991c4c8c00> [RTYPES.EXTPTRSXP]
#    dll: <class 'rpy2.rinterface.ListSexpVector'>
#    <rpy2.rinterface.ListSexpVector object at 0x7f991c4c8b40> [RTYPES.VECSXP]
#    numParameters: <class 'rpy2.rinterface.IntSexpVector'>
#    <rpy2.rinterface.IntSexpVector object at 0x7f991c4c8d40> [RTYPES.INTSXP],
#  '___NAMESPACE___': R object with classes: ('environment',) mapped to:,
#  '___S3MethodsTable___': R object with classes: ('environment',) mapped to:,
#  '_onLoad': R object with classes: ('function',) mapped to:,
#  '_onUnload': R object with classes: ('function',) mapped to:,
#  '_packageName': R object with classes: ('character',) mapped to:
#  ['fclust'],
#  'ARI_F': R object with classes: ('function',) mapped to:,
#  'centroids_FKM': R object with classes: ('function',) mapped to:,
#  'centroids_FKM_ent': R object with classes: ('function',) mapped to:,
#  'centroids_FKM_pf': R object with classes: ('function',) mapped to:,
#  'cl_memb': R object with classes: ('function',) mapped to:,
#  'cl_memb_H': R object with classes: ('function',) mapped to:,
#  'cl_memb_t': R object with classes: ('function',) mapped to:,
#  'cl_size': R object with classes: ('function',) mapped to:,
#  'cl_size_H': R object with classes: ('function',) mapped to:,
#  'distCheck': R object with classes: ('function',) mapped to:,
#  'euclidean_distance': R object with classes: ('function',) mapped to:,
#  'euclidean_distance_gk': R object with classes: ('function',) mapped to:,
#  'euclidean_distance_gkb': R object with classes: ('function',) mapped to:,
#  'euclidean_distance_medoid': R object with classes: ('function',) mapped to:,
#  'F_gk': R object with classes: ('function',) mapped to:,
#  'F_gk_ent': R object with classes: ('function',) mapped to:,
#  'F_gkb': R object with classes: ('function',) mapped to:,
#  'F_gkb_ent': R object with classes: ('function',) mapped to:,
#  'Fclust': R object with classes: ('function',) mapped to:,
#  'Fclust_compare': R object with classes: ('function',) mapped to:,
#  'Fclust_index': R object with classes: ('function',) mapped to:,
#  'FKM': R object with classes: ('function',) mapped to:,
#  'FKM_ent': R object with classes: ('function',) mapped to:,
#  'FKM_ent_noise': R object with classes: ('function',) mapped to:,
#  'FKM_gk': R object with classes: ('function',) mapped to:,
#  'FKM_gk_ent': R object with classes: ('function',) mapped to:,
#  'FKM_gk_ent_noise': R object with classes: ('function',) mapped to:,
#  'FKM_gk_noise': R object with classes: ('function',) mapped to:,
#  'FKM_gkb': R object with classes: ('function',) mapped to:,
#  'FKM_gkb_ent': R object with classes: ('function',) mapped to:,
#  'FKM_gkb_ent_noise': R object with classes: ('function',) mapped to:,
#  'FKM_gkb_noise': R object with classes: ('function',) mapped to:,
#  'FKM_med': R object with classes: ('function',) mapped to:,
#  'FKM_med_noise': R object with classes: ('function',) mapped to:,
#  'FKM_noise': R object with classes: ('function',) mapped to:,
#  'FKM_pf': R object with classes: ('function',) mapped to:,
#  'FKM_pf_noise': R object with classes: ('function',) mapped to:,
#  'Hraw': R object with classes: ('function',) mapped to:,
#  'indices': R object with classes: ('function',) mapped to:,
#  'InvCheck': R object with classes: ('function',) mapped to:,
#  'JACCARD_F': R object with classes: ('function',) mapped to:,
#  'mainFKM': R object with classes: ('function',) mapped to:,
#  'mainFKM_ent': R object with classes: ('function',) mapped to:,
#  'mainFKM_ent_noise': R object with classes: ('function',) mapped to:,
#  'mainFKM_ent_noise_U': R object with classes: ('function',) mapped to:,
#  'mainFKM_ent_U': R object with classes: ('function',) mapped to:,
#  'mainFKM_gk': R object with classes: ('function',) mapped to:,
#  'mainFKM_gk_ent': R object with classes: ('function',) mapped to:,
#  'mainFKM_gk_ent_noise': R object with classes: ('function',) mapped to:,
#  'mainFKM_gk_ent_noise_U': R object with classes: ('function',) mapped to:,
#  'mainFKM_gk_ent_U': R object with classes: ('function',) mapped to:,
#  'mainFKM_gk_noise': R object with classes: ('function',) mapped to:,
#  'mainFKM_gk_noise_U': R object with classes: ('function',) mapped to:,
#  'mainFKM_gk_U': R object with classes: ('function',) mapped to:,
#  'mainFKM_gkb': R object with classes: ('function',) mapped to:,
#  'mainFKM_gkb_ent': R object with classes: ('function',) mapped to:,
#  'mainFKM_gkb_ent_noise': R object with classes: ('function',) mapped to:,
#  'mainFKM_gkb_ent_noise_U': R object with classes: ('function',) mapped to:,
#  'mainFKM_gkb_ent_U': R object with classes: ('function',) mapped to:,
#  'mainFKM_gkb_noise': R object with classes: ('function',) mapped to:,
#  'mainFKM_gkb_noise_U': R object with classes: ('function',) mapped to:,
#  'mainFKM_gkb_U': R object with classes: ('function',) mapped to:,
#  'mainFKM_med': R object with classes: ('function',) mapped to:,
#  'mainFKM_med_noise': R object with classes: ('function',) mapped to:,
#  'mainFKM_med_noise_U': R object with classes: ('function',) mapped to:,
#  'mainFKM_med_U': R object with classes: ('function',) mapped to:,
#  'mainFKM_noise': R object with classes: ('function',) mapped to:,
#  'mainFKM_noise_U': R object with classes: ('function',) mapped to:,
#  'mainFKM_pf': R object with classes: ('function',) mapped to:,
#  'mainFKM_pf_noise': R object with classes: ('function',) mapped to:,
#  'mainFKM_pf_noise_U': R object with classes: ('function',) mapped to:,
#  'mainFKM_pf_U': R object with classes: ('function',) mapped to:,
#  'mainFKM_U': R object with classes: ('function',) mapped to:,
#  'mainnefrc': R object with classes: ('function',) mapped to:,
#  'mainnefrc_U': R object with classes: ('function',) mapped to:,
#  'mainrnefrc': R object with classes: ('function',) mapped to:,
#  'mainrnefrc_U': R object with classes: ('function',) mapped to:,
#  'Match': R object with classes: ('function',) mapped to:,
#  'medoids_FKM': R object with classes: ('function',) mapped to:,
#  'memb_degree': R object with classes: ('function',) mapped to:,
#  'memb_degree_ent': R object with classes: ('function',) mapped to:,
#  'memb_degree_medoid': R object with classes: ('function',) mapped to:,
#  'memb_degree_pf': R object with classes: ('function',) mapped to:,
#  'MPC': R object with classes: ('function',) mapped to:,
#  'NEFRC': R object with classes: ('function',) mapped to:,
#  'NEFRC_noise': R object with classes: ('function',) mapped to:,
#  'partCoef': R object with classes: ('function',) mapped to:,
#  'partCoef_mod': R object with classes: ('function',) mapped to:,
#  'partEntropy': R object with classes: ('function',) mapped to:,
#  'partition_comp': R object with classes: ('function',) mapped to:,
#  'PC': R object with classes: ('function',) mapped to:,
#  'PE': R object with classes: ('function',) mapped to:,
#  'plot_fclust': R object with classes: ('function',) mapped to:,
#  'plotFKM': R object with classes: ('function',) mapped to:,
#  'plotREL': R object with classes: ('function',) mapped to:,
#  'print_fclust': R object with classes: ('function',) mapped to:,
#  'replace': R object with classes: ('function',) mapped to:,
#  'RI_F': R object with classes: ('function',) mapped to:,
#  'SIL': R object with classes: ('function',) mapped to:,
#  'SIL_F': R object with classes: ('function',) mapped to:,
#  'silhouette': R object with classes: ('function',) mapped to:,
#  'silhouette_internal': R object with classes: ('function',) mapped to:,
#  'silhouetteFuzzy': R object with classes: ('function',) mapped to:,
#  'summary_fclust': R object with classes: ('function',) mapped to:,
#  'unifInit': R object with classes: ('function',) mapped to:,
#  'VAT': R object with classes: ('function',) mapped to:,
#  'VCV': R object with classes: ('function',) mapped to:,
#  'VCV2': R object with classes: ('function',) mapped to:,
#  'VIFCR': R object with classes: ('function',) mapped to:,
#  'XB': R object with classes: ('function',) mapped to:,
#  'xie_beni': R object with classes: ('function',) mapped to:,
#  '__version__': '2.1',
#  '__rdata__': <rpy2.robjects.packages.PackageData at 0x7f991c4f5dc0>}
